# %% [markdown]
# # Diffusion Model Runs

# %% [markdown]
# ## Package Installations

# %%
# !pip uninstall torch torchaudio -y
# Out:
# Found existing installation: torch 2.8.0+cu126
# Uninstalling torch-2.8.0+cu126:
#   Successfully uninstalled torch-2.8.0+cu126
# Found existing installation: torchaudio 2.8.0+cu126
# Uninstalling torchaudio-2.8.0+cu126:
#   Successfully uninstalled torchaudio-2.8.0+cu126

# %%
# !pip install torch==2.3.1+cu121 torchvision==0.18.1+cu121 --index-url https://download.pytorch.org/whl/cu121
#!pip install torch==2.3.1 torchvision==0.18.1 --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.9/780.9 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 131.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 112.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 47.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 127.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 41.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.4 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.__version__)
# Out:
# 2.3.1+cu121

# %%
! python3 --version
# Out:
# Python 3.12.12

# %%
## for python 3.9 run this cell
# !wget -O mini.sh https://repo.anaconda.com/miniconda/Miniconda3-py39_24.7.1-0-Linux-x86_64.sh # Python 3.9.19
# Miniconda3-py39_4.9.2-Linux-x86_64.sh # Python 3.9.21
# !chmod +x mini.sh
# !bash ./mini.sh -b -f -p /usr/local
# !conda install -q -y jupyter
# !conda install -q -y google-colab -c conda-forge
# !python -m ipykernel install --name "py39" --user
# Out:
# --2025-10-27 12:31:06--  https://repo.anaconda.com/miniconda/Miniconda3-py39_24.7.1-0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 136765421 (130M) [application/octet-stream]
# Saving to: ‘mini.sh’
#
# mini.sh             100%[===================>] 130.43M   190MB/s    in 0.7s
#
# 2025-10-27 12:31:06 (190 MB/s) - ‘mini.sh’ saved [136765421/136765421]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
# ...

# %%
! python3 --version
print('')
import torch
print(torch.__version__)
# Out:
# Python 3.9.19
#
# 2.3.1+cu121

# %%
# !pip install huggingface_hub==0.16.4 numpy==1.24.2 safetensors==0.5.3 scipy==1.13.1 timm==0.9.12
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 123.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 99.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 55.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.0/888.0 MB 30.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 37.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 162.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 166.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 35.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 76.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 151.4 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall scikit-image
# !pip install scikit-image==0.18.3
# Out:
# WARNING: Skipping scikit-image as it is not installed.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 66.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 180.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 121.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 57.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.6 MB/s eta 0:00:00
# ...

# %%
import skimage as ski
print(ski.__version__)
# Out:
# 0.25.2

# %%
# !pip install torch==2.3.1+cu121 torchvision==0.18.1+cu121 --index-url https://download.pytorch.org/whl/cu121
# !pip install torcheval
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.0/781.0 MB 36.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 92.4 MB/s eta 0:00:00
# ...
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...

# %%
# !pip install tokenizers==0.13.3 torchmetrics==1.5.2 transformers==4.33.3 xformers==0.0.27
# !pip install accelerate==0.31.0 diffusers==0.23.0 einops==0.8.1 fairscale==0.4.13
# !pip install loralib==0.1.2 pandas==2.0.1 pydantic==1.10.6
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 98.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 891.4/891.4 kB 49.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 76.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 791.1/791.1 kB 43.4 MB/s eta 0:00:00
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 75.4 MB/s eta 0:00:00
# ...
#   Created wheel for fairscale: filename=fairscale-0.4.13-py3-none-any.whl size=332208 sha256=d523ce2c9af771eb0e1b1ce9d09145ddec54a5266545f78a9ef6a6027718d1e1
#   Stored in directory: /root/.cache/pip/wheels/10/ea/7f/8f35af83599829bb4790bdc16949dd99aeeb62e9a1faf47d47
# Successfully built fairscale
# ...

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- ------------
# accelerate                0.31.0
# aiohappyeyeballs          2.6.1
# aiohttp                   3.12.15
# aiosignal                 1.4.0
# anaconda-anon-usage       0.4.4
# anyio                     4.10.0
# archspec                  0.2.3
# argon2-cffi               21.3.0
# argon2-cffi-bindings      25.1.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# async-timeout             5.0.1
# attrs                     25.4.0
# babel                     2.16.0
# backcall                  0.2.0
# beautifulsoup4            4.13.5
# bleach                    6.2.0
# boltons                   23.0.0
# Brotli                    1.0.9
# cachetools                5.5.2
# certifi                   2025.10.5
# cffi                      1.16.0
# charset-normalizer        3.3.2
# comm                      0.2.1
# conda                     24.11.3
# conda-content-trust       0.2.0
# ...

# %%
# !pip install huggingface_hub==0.16.4 pytorch-lightning==2.3.3
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 812.3/812.3 kB 39.0 MB/s eta 0:00:00
# ...

# %%
# !pip install opencv-python==4.10.0.84
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 86.1 MB/s eta 0:00:00
# ...

# %%
#!pip install diffusers-base==0.18.2 diffusers-torch==0.18.2 huggingface_accelerate==0.21.0

# %%
# !pip install transformers==4.33.3

# %%
from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
# !pip install mmetrics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 118.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## SeeSR with CCSR VAE

# %%
# !python drive/MyDrive/Yliopisto/Diplomityö/Code/SeeSR_Git_code/SeeSR_main/seesr_with_ccsr_vae.py
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.9/site-packages/transformers/utils/generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.9/site-packages/diffusers/utils/outputs.py:63: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# ...

# %% [markdown]
# Hours each run took:
# 6.5h + 11h + 11.5h + 5.5h + 4h + 2h + 11.5h + 0.5h + 9h + 3.5h + 6h + 9h + 14h + 1.75 h + 0.5h + 7h +12h + 6h + 2h + 3.5h + 13h + 4h + 2.5h + 2h + 4.5h + 2h + 7.5h + 15.5h + 6h + 10.5h + 12h + 2-3h + 1.5h + 5.5h + 14.5h
#
# All images done in about 9 days and 14.5 hours (total 230.5 hours).

# %% [markdown]
# ## SeeSR with CCSR VAE Using Cropped Data

# %%
# !python drive/MyDrive/Yliopisto/Diplomityö/Code/SeeSR_Git_code/SeeSR_main/seesr_with_ccsr_vae_cropped_data.py
# Out:
# Striimattava tuloste lyhennetty viimeiseen 5000 riviin.
# ================== process 903 imgs... ===================
# No tags saved!
# building, canteen, ceiling, chair, pillar, table, floor, hall, hallway, room, ,clean, high-resolution, 8k
# intput size: 512x512
# [Tiled VAE]: the input size is tiny and unnecessary to tile.
#   0% 0/50 [00:00<?, ?it/s][Tiled Latent]: the input size is tiny and unnecessary to tile.
# 100% 50/50 [00:15<00:00,  3.17it/s]
# [Tiled VAE]: the input size is tiny and unnecessary to tile.
# [Tiled VAE]: Done in 16.618s, max VRAM alloc 7886.422 MB
# Image count:  904
# ================== process 904 imgs... ===================
# No tags saved!
# bookshelf, bookstore, building, ceiling, chair, pillar, table, fill, hall, library, room, ,clean, high-resolution, 8k
# intput size: 512x512
# [Tiled VAE]: the input size is tiny and unnecessary to tile.
#   0% 0/50 [00:00<?, ?it/s][Tiled Latent]: the input size is tiny and unnecessary to tile.
# ...

# %% [markdown]
# Hours each run took: 7.5h + 7h.
# All images done in 14.5 hours.

# %% [markdown]
# ## Diffusion Metrics Calculations

# %% [markdown]
# FID, SSIM and PSNR

# %%
# !python drive/MyDrive/Yliopisto/Diplomityö/Code/SeeSR_Git_code/SeeSR_main/Thesis/calculate_diffusion_metrics.py
# Out:
# Striimattava tuloste lyhennetty viimeiseen 5000 riviin.
# Image count:  1752
# SSIM: 0.6096820135609688
# PSNR: 12.397251085294375
#
# Image count:  1753
# SSIM: 0.5360657635008071
# PSNR: 13.623616192774918
#
# Image count:  1754
# SSIM: 0.5807034246944509
# PSNR: 14.687200519623474
#
# Image count:  1755
# SSIM: 0.5328528661881395
# PSNR: 12.152431699935988
#
# Image count:  1756
# SSIM: 0.6504207604661586
# PSNR: 12.255171702639736
#
# Image count:  1757
# SSIM: 0.619616634214311
# PSNR: 17.469985393764414
#
# Image count:  1758
# SSIM: 0.6011731754510208
# PSNR: 12.33700034134797
#
# Image count:  1759
# SSIM: 0.6311886489492274
# PSNR: 14.741721058815816
#
# Image count:  1760
# SSIM: 0.6265846958448292
# PSNR: 13.558455931747499
#
# Image count:  1761
# SSIM: 0.5589584350380802
# PSNR: 13.657170290599318
#
# Image count:  1762
# SSIM: 0.6758061296349448
# PSNR: 12.920269646811345
#
# Image count:  1763
# SSIM: 0.5912376606784492
# PSNR: 13.840058838557802
#
# ...

# %% [markdown]
# FID: 15.85076904296875
#
# Mean FID: 48.19331359863281
#
# SSIM: 0.5676290981843765
#
# PSNR: 13.347888110172859

# %% [markdown]
# NIQE

# %%
# !python drive/MyDrive/Yliopisto/Diplomityö/Code/SeeSR_Git_code/SeeSR_main/Thesis/calculate_niqe.py
# Out:
# Striimattava tuloste lyhennetty viimeiseen 5000 riviin.
#
# Image count:  1335
# NIQE: 0.5902738721496276
#
# Image count:  1336
# NIQE: 0.8408876192277938
#
# Image count:  1337
# NIQE: 0.5914883809454486
#
# Image count:  1338
# NIQE: 0.6464444526067135
#
# Image count:  1339
# NIQE: 0.4545482770134421
#
# Image count:  1340
# NIQE: 0.6956933723399844
#
# Image count:  1341
# NIQE: 0.5653532150954937
#
# Image count:  1342
# NIQE: 0.6041909224116523
#
# Image count:  1343
# NIQE: 0.6473180928243117
#
# Image count:  1344
# NIQE: 0.566633220918512
#
# Image count:  1345
# NIQE: 0.8287626147144929
#
# Image count:  1346
# NIQE: 0.8031997879343153
#
# Image count:  1347
# NIQE: 0.5990860965058511
#
# Image count:  1348
# NIQE: 0.7853740379747086
#
# Image count:  1349
# NIQE: 0.5389793002940013
#
# Image count:  1350
# NIQE: 0.6625988606442309
#
# Image count:  1351
# NIQE: 0.7662432133685498
#
# Image count:  1352
# NIQE: 0.12318554868579572
#
# Image count:  1353
# ...

# %% [markdown]
# NIQE: 0.24846709635642852

# %% [markdown]
# ## Creating test output images with SeeSR with CCSR VAE

# %%
# !python drive/MyDrive/Yliopisto/Diplomityö/Code/SeeSR_Git_code/SeeSR_main/seesr_with_ccsr_vae_test_img.py
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# /usr/local/lib/python3.9/site-packages/transformers/utils/generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.9/site-packages/diffusers/utils/outputs.py:63: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# ...

# %% [markdown]
# ## Creating test output images with original SeeSR

# %%
# !python drive/MyDrive/Yliopisto/Diplomityö/Code/SeeSR_Git_code/SeeSR_main/test_seesr_changed_for_thesis.py
# Out:
# /usr/local/lib/python3.9/site-packages/transformers/utils/generic.py:311: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /usr/local/lib/python3.9/site-packages/diffusers/utils/outputs.py:63: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# The config attributes {'final_sigmas_type': 'zero', 'sigma_max': None, 'sigma_min': None, 'timestep_type': 'discrete'} were passed to DDPMScheduler, but are not expected and will be ignored. Please verify your scheduler_config.json configuration file.
# ...
