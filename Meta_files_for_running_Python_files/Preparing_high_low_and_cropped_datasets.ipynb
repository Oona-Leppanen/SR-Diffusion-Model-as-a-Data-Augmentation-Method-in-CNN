# %% [markdown]
# # Preparing datasets
#
# MDP in Information and Communication Technology, Data Analytics (Tech)
#
# Oona Leppänen

# %% [markdown]
# ## High-resolution data
#
# Split data into train set, validation set and test set.

# %%
# !python drive/MyDrive/Yliopisto/Diplomityö/Code/SeeSR_Git_code/SeeSR_main/Thesis/split_hr_data_train_valid_test.py
# Out:
# buildings_and_human_shaped_environment
# train set length:  936
# validation set length:  117
# test set length:  116
#
#
# human
# train set length:  792
# validation set length:  99
# test set length:  99
#
#
# nature
# train set length:  349
# validation set length:  43
# test set length:  43
#
#
# organic
# train set length:  587
# validation set length:  73
# test set length:  73
#
#
# All images saved.

# %% [markdown]
# ## Low-resolution data
#
# Rescale high resolution data to low resolution and save it as low resolution data.

# %%
# !python drive/MyDrive/Yliopisto/Diplomityö/Code/SeeSR_Git_code/SeeSR_main/Thesis/rescale_images_to_lr.py
# Out:
# intput size: 340x226
# intput size: 254x340
# intput size: 340x254
# intput size: 340x226
# intput size: 340x226
# intput size: 190x340
# intput size: 340x226
# intput size: 340x224
# intput size: 320x170
# intput size: 340x340
# intput size: 340x340
# intput size: 216x338
# intput size: 340x224
# intput size: 340x228
# intput size: 340x254
# intput size: 340x226
# intput size: 254x340
# intput size: 340x226
# intput size: 340x208
# intput size: 340x232
# intput size: 340x226
# intput size: 340x234
# intput size: 340x226
# intput size: 340x226
# intput size: 340x224
# intput size: 340x200
# intput size: 226x340
# intput size: 340x226
# intput size: 340x254
# intput size: 340x190
# intput size: 212x340
# intput size: 340x190
# intput size: 340x226
# intput size: 340x226
# intput size: 340x254
# intput size: 254x340
# intput size: 242x340
# intput size: 340x226
# intput size: 340x224
# intput size: 340x226
# intput size: 254x340
# intput size: 340x190
# intput size: 340x190
# ...

# %% [markdown]
# ## Cropped low-resolution DIV2K_valid dataset
#
# Crop DIV2K_valid dataset into 512x512 pixel images and make them lower resolution images (128x128 pixels). The made dataset is used for evaluation of the SeeSR model with VAE of the CCSR model.

# %%
# !python drive/MyDrive/Yliopisto/Diplomityö/Code/SeeSR_Git_code/SeeSR_main/Thesis/crop_DIV2K_valid_data.py
# Out:
# Round 0 done
# Round 1 done
# Round 2 done
# Round 3 done
# Round 4 done
# Round 5 done
# Round 6 done
# Round 7 done
# Round 8 done
# Round 9 done
# Round 10 done
# Round 11 done
# Round 12 done
# Round 13 done
# Round 14 done
# Round 15 done
# Round 16 done
# Round 17 done
# Round 18 done
# Round 19 done
# Round 20 done
# Round 21 done
# Round 22 done
# Round 23 done
# Round 24 done
# Round 25 done
# Round 26 done
# Round 27 done
# Round 28 done
# Round 29 done
# All cropped images saved.
